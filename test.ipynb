# %%
import pandas as pd

# %%
pd.read_csv('./data/GANData.csv')
# Out:
#          ASSETTYPE        ASSETSUBTYPE                          ASSETNAME  \
# 0      Alternative            Property       Global Property USD Unhedged
# 1      Alternative            Property       Global Property USD Unhedged
# 2      Alternative            Property       Global Property USD Unhedged
# 3      Alternative            Property       Global Property USD Unhedged
# 4      Alternative            Property       Global Property USD Unhedged
# ...            ...                 ...                                ...
# 36535     Risky FI  Corporate Bonds IG  USD Corporate Bond - USD Unhedged
# 36536     Risky FI  Corporate Bonds IG  USD Corporate Bond - USD Unhedged
# 36537     Risky FI  Corporate Bonds IG  USD Corporate Bond - USD Unhedged
# 36538     Risky FI  Corporate Bonds IG  USD Corporate Bond - USD Unhedged
# 36539     Risky FI  Corporate Bonds IG  USD Corporate Bond - USD Unhedged
#
#        ISHEDGED                                     INDEXPROXYNAME  VALUEDATE  \
# ...
